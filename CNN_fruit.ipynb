# %%
#Kết nối Drive với ggcolab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator, image
from keras.layers import Dense,Activation,Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras.models import  Sequential

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %%
train_data = '/content/drive/MyDrive/AI/10_TraiCay/TRAIN'
test_data =  '/content/drive/MyDrive/AI/10_TraiCay/TEST'
val_data  =  '/content/drive/MyDrive/AI/10_TraiCay/TEST'

# %%
from keras.engine.data_adapter import train_validation_split
#CHỈNH LẠI TỈ LỆ VÀ PRE-PREPROCESSING DATA

data_scale = ImageDataGenerator(
              rescale=1. / 255,
              shear_range=0.2,
              zoom_range=0.2,
              horizontal_flip=True)

train_input = data_scale.flow_from_directory(train_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
test_input = data_scale.flow_from_directory(test_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
val_input = data_scale.flow_from_directory(val_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
# Out:
# Found 360 images belonging to 10 classes.
# Found 105 images belonging to 10 classes.
# Found 105 images belonging to 10 classes.

# %%
#ĐẶT NHÃN
class_name = ['ca_rot', 'cam', 'chuoi', 'mang_cau', 'man', 'nhan', 'oi', 'sau_rieng', 'tao','xoai']

#IN NHÃN VÀ ĐẶT GIÁ TRỊ CHO TỪNG PHẦN TỬ
print("labels: ", class_name)
print("match class: ", train_input.class_indices)
print("Tổng cộng có các loại trái cây: ",train_input.num_classes)
# Out:
# labels:  ['ca_rot', 'cam', 'chuoi', 'mang_cau', 'man', 'nhan', 'oi', 'sau_rieng', 'tao', 'xoai']
# match class:  {'Cam': 0, 'Cà rốt': 1, 'Chuối': 2, 'Mãng cầu': 3, 'Mận': 4, 'Nhãn': 5, 'Ổi': 6, 'Sầu riêng': 7, 'Táo': 8, 'Xoài': 9}
# Tổng cộng có các loại trái cây:  10

# %%
#XÂY DỰNG MODEL CNN
model=Sequential()

#TRÍCH XUẤT TẬP DỮ LIỆU(FEATURE EXTRACTORS)
#LAYER 1
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same', input_shape=(120,120,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 2
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 3
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

#FULLY CONNECTED LAYER
#Flatten Layer is used to change the dimension of output from convolution layer, which has 3D, to 2D output
model.add(Flatten())

#Dense(512) is a fully-connected layer with 128 hidden units
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(10,activation='softmax'))  #10 class_name
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 120, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 32)       0
#  )
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 512)               14746112
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 15,107,146
# Trainable params: 15,107,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
fruit_train = model.fit(train_input,batch_size=30,epochs=50,verbose=1,validation_data=val_input)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 113s 10s/step - loss: 6.6879 - accuracy: 0.1139 - val_loss: 2.2809 - val_accuracy: 0.1238
# Epoch 2/50
# 12/12 [==============================] - 15s 1s/step - loss: 2.1625 - accuracy: 0.1833 - val_loss: 2.1367 - val_accuracy: 0.1905
# Epoch 3/50
# 12/12 [==============================] - 15s 1s/step - loss: 1.8743 - accuracy: 0.3111 - val_loss: 1.8860 - val_accuracy: 0.2476
# Epoch 4/50
# 12/12 [==============================] - 14s 1s/step - loss: 1.6034 - accuracy: 0.3722 - val_loss: 1.7164 - val_accuracy: 0.4095
# Epoch 5/50
# 12/12 [==============================] - 15s 1s/step - loss: 1.3803 - accuracy: 0.4639 - val_loss: 1.6330 - val_accuracy: 0.4286
# Epoch 6/50
# 12/12 [==============================] - 14s 1s/step - loss: 1.3341 - accuracy: 0.4417 - val_loss: 1.7371 - val_accuracy: 0.4571
# Epoch 7/50
# 12/12 [==============================] - 14s 1s/step - loss: 1.2338 - accuracy: 0.4833 - val_loss: 1.6759 - val_accuracy: 0.4762
# Epoch 8/50
# 12/12 [==============================] - 14s 1s/step - loss: 1.1428 - accuracy: 0.5528 - val_loss: 1.7688 - val_accuracy: 0.4190
# Epoch 9/50
# 12/12 [==============================] - 14s 1s/step - loss: 1.0345 - accuracy: 0.5750 - val_loss: 1.8083 - val_accuracy: 0.5238
# Epoch 10/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.8919 - accuracy: 0.6528 - val_loss: 1.9384 - val_accuracy: 0.5905
# Epoch 11/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.9323 - accuracy: 0.6000 - val_loss: 1.7608 - val_accuracy: 0.5143
# Epoch 12/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.9477 - accuracy: 0.6000 - val_loss: 1.7479 - val_accuracy: 0.5143
# Epoch 13/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.9017 - accuracy: 0.6528 - val_loss: 1.8710 - val_accuracy: 0.6571
# Epoch 14/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.7608 - accuracy: 0.6944 - val_loss: 1.9848 - val_accuracy: 0.5524
# Epoch 15/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.7478 - accuracy: 0.6611 - val_loss: 1.9881 - val_accuracy: 0.6667
# Epoch 16/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.7227 - accuracy: 0.7139 - val_loss: 2.2575 - val_accuracy: 0.6571
# Epoch 17/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.7305 - accuracy: 0.7167 - val_loss: 2.1126 - val_accuracy: 0.6667
# Epoch 18/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.6563 - accuracy: 0.7333 - val_loss: 2.3558 - val_accuracy: 0.6000
# Epoch 19/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.7589 - accuracy: 0.7194 - val_loss: 2.3424 - val_accuracy: 0.7048
# Epoch 20/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.6097 - accuracy: 0.7750 - val_loss: 2.2071 - val_accuracy: 0.6000
# Epoch 21/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.6518 - accuracy: 0.7389 - val_loss: 2.2059 - val_accuracy: 0.7048
# Epoch 22/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.5912 - accuracy: 0.7750 - val_loss: 2.3384 - val_accuracy: 0.6476
# Epoch 23/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5420 - accuracy: 0.7583 - val_loss: 2.2635 - val_accuracy: 0.6571
# Epoch 24/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.4626 - accuracy: 0.8222 - val_loss: 2.5750 - val_accuracy: 0.6571
# Epoch 25/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5850 - accuracy: 0.7583 - val_loss: 2.3938 - val_accuracy: 0.6571
# Epoch 26/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5433 - accuracy: 0.7806 - val_loss: 2.8315 - val_accuracy: 0.6000
# Epoch 27/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5912 - accuracy: 0.7778 - val_loss: 2.6640 - val_accuracy: 0.6667
# Epoch 28/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5755 - accuracy: 0.8000 - val_loss: 1.6836 - val_accuracy: 0.7048
# Epoch 29/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.4630 - accuracy: 0.8500 - val_loss: 2.3980 - val_accuracy: 0.6952
# Epoch 30/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5069 - accuracy: 0.7972 - val_loss: 2.7333 - val_accuracy: 0.6381
# Epoch 31/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.5197 - accuracy: 0.8194 - val_loss: 2.2873 - val_accuracy: 0.6667
# Epoch 32/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.4094 - accuracy: 0.8333 - val_loss: 2.7695 - val_accuracy: 0.6571
# Epoch 33/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.4437 - accuracy: 0.8361 - val_loss: 2.3481 - val_accuracy: 0.6571
# Epoch 34/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.4197 - accuracy: 0.8333 - val_loss: 2.1791 - val_accuracy: 0.7524
# Epoch 35/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.3658 - accuracy: 0.8611 - val_loss: 2.4199 - val_accuracy: 0.6667
# Epoch 36/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.3643 - accuracy: 0.8583 - val_loss: 2.2813 - val_accuracy: 0.7524
# Epoch 37/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.3721 - accuracy: 0.8722 - val_loss: 2.6361 - val_accuracy: 0.7429
# Epoch 38/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.2779 - accuracy: 0.8778 - val_loss: 2.5973 - val_accuracy: 0.7810
# Epoch 39/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.2646 - accuracy: 0.8944 - val_loss: 3.1005 - val_accuracy: 0.6857
# Epoch 40/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.2947 - accuracy: 0.9000 - val_loss: 2.7990 - val_accuracy: 0.6762
# Epoch 41/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.3432 - accuracy: 0.8667 - val_loss: 2.4186 - val_accuracy: 0.7143
# Epoch 42/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.3121 - accuracy: 0.8778 - val_loss: 3.0393 - val_accuracy: 0.7524
# Epoch 43/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.2879 - accuracy: 0.9139 - val_loss: 2.8359 - val_accuracy: 0.7429
# Epoch 44/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.2526 - accuracy: 0.9056 - val_loss: 2.8523 - val_accuracy: 0.7333
# Epoch 45/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.2308 - accuracy: 0.9111 - val_loss: 3.0456 - val_accuracy: 0.7619
# Epoch 46/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.2507 - accuracy: 0.9222 - val_loss: 2.4309 - val_accuracy: 0.7714
# Epoch 47/50
# 12/12 [==============================] - 15s 1s/step - loss: 0.2368 - accuracy: 0.9139 - val_loss: 2.4665 - val_accuracy: 0.8000
# Epoch 48/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.2128 - accuracy: 0.9139 - val_loss: 2.9437 - val_accuracy: 0.7238
# Epoch 49/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.1992 - accuracy: 0.9250 - val_loss: 2.8627 - val_accuracy: 0.7714
# Epoch 50/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.1489 - accuracy: 0.9444 - val_loss: 2.9055 - val_accuracy: 0.7714

# %%
model.save('/content/drive/MyDrive/AI/10_TraiCay/fruit.h5')

# %%
pic = image.load_img('/content/drive/MyDrive/AI/10_TraiCay/Xoai.jpg', target_size=(120,120)) 
plt.imshow(pic)
pic = img_to_array(pic)
pic = pic.reshape(1,120,120,3) 
pic = pic.astype('float32')
pic = pic/255
np.argmax(model.predict(pic), axis=1)
# Out:
# array([9])

# %%
# predict 
guess=np.argmax(model.predict(pic), axis=1)
#đặt điều kiện
if guess[0]==0:
  print("Loai trai cay: Ca_rot")
if guess[0]==1:
  print("Loai trai cay: Cam")
if guess[0]==2:
  print("Loai trai cay: Chuoi")
if guess[0]==3:
  print("Loai trai cay: Mang_cau")
if guess[0]==4:
  print("Loai trai cay: Man")
if guess[0]==5:
  print("Loai trai cay: Nhan")
if guess[0]==6:
  print("Loai trai cay: Oi")
if guess[0]==7:
  print("Loai trai cay: Sau_rieng")
if guess[0]==8:
  print("Loai trai cay: tao")
if guess[0]==9:
  print("Loai trai cay: xoai")
# Out:
# Loai trai cay: xoai
