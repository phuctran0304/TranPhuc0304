# %%
#Kết nối Drive với ggcolab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator, image
from keras.layers import Dense,Activation,Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras.models import  Sequential

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd

# %%
train_data = '/content/drive/MyDrive/AI/10_MonAn/TRAIN'
test_data =  '/content/drive/MyDrive/AI/10_MonAn/TEST'
val_data  =  '/content/drive/MyDrive/AI/10_MonAn/TEST'

# %%
from keras.engine.data_adapter import train_validation_split
#CHỈNH LẠI TỈ LỆ VÀ PRE-PREPROCESSING DATA

data_scale = ImageDataGenerator(
              rescale=1. / 255,
              shear_range=0.2,
              zoom_range=0.2,
              horizontal_flip=True)

train_input = data_scale.flow_from_directory(train_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
test_input = data_scale.flow_from_directory(test_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
val_input = data_scale.flow_from_directory(val_data,
                        target_size=(120, 120),
                        batch_size=32,
                        class_mode="categorical")
# Out:
# Found 283 images belonging to 10 classes.
# Found 123 images belonging to 10 classes.
# Found 123 images belonging to 10 classes.

# %%
#ĐẶT NHÃN
class_name = ['Banh mi', 'Banh uot', 'Banh xeo', 'Bun rieu', 'Ca ri', 'Che buoi', 'Com tam', 'Mi xao', 'Pho', 'Thit kho tau']

#IN NHÃN VÀ ĐẶT GIÁ TRỊ CHO TỪNG PHẦN TỬ
print("labels: ", class_name)
print("match class: ", train_input.class_indices)
print("Tong cong co cac loai mon an: ",train_input.num_classes)
# Out:
# labels:  ['Banh mi', 'Banh uot', 'Banh xeo', 'Bun rieu', 'Ca ri', 'Che buoi', 'Com tam', 'Mi xao', 'Pho', 'Thit kho tau']
# match class:  {'Bánh Mì': 0, 'Bánh ướt': 1, 'Bánh xèo': 2, 'Bún riêu': 3, 'Cà ri': 4, 'Chè bưởi': 5, 'Cơm tấm': 6, 'Mì xào': 7, 'Phở': 8, 'Thị kho tàu': 9}
# Tong cong co cac loai mon an:  10

# %%
#XÂY DỰNG MODEL CNN
model=Sequential()

#TRÍCH XUẤT TẬP DỮ LIỆU(FEATURE EXTRACTORS)
#LAYER 1
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same', input_shape=(120,120,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 2
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
#LAYER 3
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

#FULLY CONNECTED LAYER
#Flatten Layer is used to change the dimension of output from convolution layer, which has 3D, to 2D output
model.add(Flatten())

#Dense(512) is a fully-connected layer with 128 hidden units
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(10,activation='softmax'))  #10 class_name
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 120, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 32)       0
#  )
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 512)               14746112
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 15,107,146
# Trainable params: 15,107,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
food_train = model.fit(train_input,batch_size=30,epochs=60,verbose=1,validation_data=val_input)
# Out:
# Epoch 1/60
# 9/9 [==============================] - 111s 14s/step - loss: 15.8774 - accuracy: 0.0883 - val_loss: 2.2907 - val_accuracy: 0.1301
# Epoch 2/60
# 9/9 [==============================] - 12s 1s/step - loss: 2.3234 - accuracy: 0.1272 - val_loss: 2.3026 - val_accuracy: 0.1057
# Epoch 3/60
# 9/9 [==============================] - 12s 1s/step - loss: 2.3013 - accuracy: 0.1343 - val_loss: 2.3030 - val_accuracy: 0.1057
# Epoch 4/60
# 9/9 [==============================] - 12s 1s/step - loss: 2.2922 - accuracy: 0.0954 - val_loss: 2.2660 - val_accuracy: 0.1057
# Epoch 5/60
# 9/9 [==============================] - 12s 1s/step - loss: 2.2262 - accuracy: 0.1131 - val_loss: 2.2245 - val_accuracy: 0.1301
# Epoch 6/60
# 9/9 [==============================] - 12s 1s/step - loss: 2.1289 - accuracy: 0.1802 - val_loss: 2.0861 - val_accuracy: 0.3089
# Epoch 7/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.9847 - accuracy: 0.2792 - val_loss: 2.0367 - val_accuracy: 0.3089
# Epoch 8/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.6877 - accuracy: 0.4028 - val_loss: 1.8184 - val_accuracy: 0.3821
# Epoch 9/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.5891 - accuracy: 0.4346 - val_loss: 1.7283 - val_accuracy: 0.4797
# Epoch 10/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.5395 - accuracy: 0.4240 - val_loss: 1.8332 - val_accuracy: 0.3415
# Epoch 11/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.5064 - accuracy: 0.4382 - val_loss: 1.6464 - val_accuracy: 0.4065
# Epoch 12/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.3324 - accuracy: 0.5159 - val_loss: 1.6869 - val_accuracy: 0.3821
# Epoch 13/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.2661 - accuracy: 0.5936 - val_loss: 1.4878 - val_accuracy: 0.4390
# Epoch 14/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.1548 - accuracy: 0.5866 - val_loss: 1.5436 - val_accuracy: 0.4553
# Epoch 15/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.1406 - accuracy: 0.5724 - val_loss: 1.6173 - val_accuracy: 0.4472
# Epoch 16/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.1023 - accuracy: 0.6219 - val_loss: 1.5581 - val_accuracy: 0.4797
# Epoch 17/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.0423 - accuracy: 0.6325 - val_loss: 1.3082 - val_accuracy: 0.5610
# Epoch 18/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.9685 - accuracy: 0.6290 - val_loss: 1.5657 - val_accuracy: 0.4553
# Epoch 19/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.9352 - accuracy: 0.6537 - val_loss: 1.3458 - val_accuracy: 0.5285
# Epoch 20/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.8976 - accuracy: 0.6855 - val_loss: 1.2675 - val_accuracy: 0.5772
# Epoch 21/60
# 9/9 [==============================] - 12s 1s/step - loss: 1.0324 - accuracy: 0.6360 - val_loss: 1.3741 - val_accuracy: 0.5610
# Epoch 22/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.8779 - accuracy: 0.7102 - val_loss: 1.4397 - val_accuracy: 0.5122
# Epoch 23/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.8228 - accuracy: 0.7385 - val_loss: 1.4586 - val_accuracy: 0.5610
# Epoch 24/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.7522 - accuracy: 0.7420 - val_loss: 1.1912 - val_accuracy: 0.6585
# Epoch 25/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.6859 - accuracy: 0.7668 - val_loss: 1.1200 - val_accuracy: 0.6098
# Epoch 26/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.5384 - accuracy: 0.8233 - val_loss: 1.0970 - val_accuracy: 0.6341
# Epoch 27/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.6349 - accuracy: 0.7739 - val_loss: 1.1137 - val_accuracy: 0.6260
# Epoch 28/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.4506 - accuracy: 0.8516 - val_loss: 1.0824 - val_accuracy: 0.6829
# Epoch 29/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.4031 - accuracy: 0.8657 - val_loss: 1.3101 - val_accuracy: 0.5772
# Epoch 30/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.4401 - accuracy: 0.8445 - val_loss: 1.2566 - val_accuracy: 0.6667
# Epoch 31/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.3996 - accuracy: 0.8445 - val_loss: 1.1013 - val_accuracy: 0.6504
# Epoch 32/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.3183 - accuracy: 0.8975 - val_loss: 1.2844 - val_accuracy: 0.6585
# Epoch 33/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.3282 - accuracy: 0.8728 - val_loss: 1.1717 - val_accuracy: 0.7154
# Epoch 34/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.4756 - accuracy: 0.8763 - val_loss: 1.0908 - val_accuracy: 0.6748
# Epoch 35/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.4824 - accuracy: 0.8339 - val_loss: 1.4835 - val_accuracy: 0.5691
# Epoch 36/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.3683 - accuracy: 0.8940 - val_loss: 1.0252 - val_accuracy: 0.6992
# Epoch 37/60
# 9/9 [==============================] - 13s 1s/step - loss: 0.2474 - accuracy: 0.9117 - val_loss: 0.9366 - val_accuracy: 0.7154
# Epoch 38/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2890 - accuracy: 0.9081 - val_loss: 1.2682 - val_accuracy: 0.6504
# Epoch 39/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1768 - accuracy: 0.9364 - val_loss: 0.9297 - val_accuracy: 0.7317
# Epoch 40/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2463 - accuracy: 0.9117 - val_loss: 0.9995 - val_accuracy: 0.7398
# Epoch 41/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1874 - accuracy: 0.9470 - val_loss: 0.8422 - val_accuracy: 0.7480
# Epoch 42/60
# 9/9 [==============================] - 13s 1s/step - loss: 0.2189 - accuracy: 0.9293 - val_loss: 1.2036 - val_accuracy: 0.7317
# Epoch 43/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2476 - accuracy: 0.8975 - val_loss: 1.1127 - val_accuracy: 0.7317
# Epoch 44/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1640 - accuracy: 0.9435 - val_loss: 1.1508 - val_accuracy: 0.6992
# Epoch 45/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1956 - accuracy: 0.9364 - val_loss: 1.5056 - val_accuracy: 0.6748
# Epoch 46/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2732 - accuracy: 0.9046 - val_loss: 1.2528 - val_accuracy: 0.6016
# Epoch 47/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2361 - accuracy: 0.9364 - val_loss: 1.1747 - val_accuracy: 0.6829
# Epoch 48/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1696 - accuracy: 0.9470 - val_loss: 1.1322 - val_accuracy: 0.7642
# Epoch 49/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1620 - accuracy: 0.9470 - val_loss: 1.1641 - val_accuracy: 0.6992
# Epoch 50/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.0887 - accuracy: 0.9717 - val_loss: 1.2064 - val_accuracy: 0.6911
# Epoch 51/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1332 - accuracy: 0.9541 - val_loss: 1.3379 - val_accuracy: 0.7073
# Epoch 52/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.0981 - accuracy: 0.9717 - val_loss: 0.9545 - val_accuracy: 0.7724
# Epoch 53/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.0954 - accuracy: 0.9647 - val_loss: 1.2170 - val_accuracy: 0.7236
# Epoch 54/60
# 9/9 [==============================] - 13s 1s/step - loss: 0.1321 - accuracy: 0.9470 - val_loss: 1.2601 - val_accuracy: 0.6992
# Epoch 55/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1280 - accuracy: 0.9541 - val_loss: 1.1057 - val_accuracy: 0.6911
# Epoch 56/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.2476 - accuracy: 0.9223 - val_loss: 1.1770 - val_accuracy: 0.7154
# Epoch 57/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1555 - accuracy: 0.9505 - val_loss: 0.9836 - val_accuracy: 0.7398
# Epoch 58/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.0805 - accuracy: 0.9859 - val_loss: 1.1597 - val_accuracy: 0.7154
# Epoch 59/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1162 - accuracy: 0.9505 - val_loss: 0.9389 - val_accuracy: 0.7561
# Epoch 60/60
# 9/9 [==============================] - 12s 1s/step - loss: 0.1161 - accuracy: 0.9576 - val_loss: 0.9251 - val_accuracy: 0.7398

# %%
model.save('/content/drive/MyDrive/AI/10_MonAn/Food.h5')

# %%
pic = image.load_img('/content/drive/MyDrive/AI/10_MonAn/Pho.jpg', target_size=(120,120)) 
plt.imshow(pic)
pic = img_to_array(pic)
pic = pic.reshape(1,120,120,3) 
pic = pic.astype('float32')
pic = pic/255
np.argmax(model.predict(pic), axis=1)
# Out:
# array([8])

# %%
# predict 
guess=np.argmax(model.predict(pic), axis=1)
#đặt điều kiện
if guess[0]==0:
  print("mon an: Banh mi")
if guess[0]==1:
  print("mon an: Banh uot")
if guess[0]==2:
  print("mon an: Banh xeo")
if guess[0]==3:
  print("mon an: Banh uot")
if guess[0]==4:
  print("mon an: Ca ri")
if guess[0]==5:
  print("mon an: Che buoi")
if guess[0]==6:
  print("mon an: Com tam")
if guess[0]==7:
  print("mon an: Mi xao")
if guess[0]==8:
  print("mon an: Pho")
if guess[0]==9:
  print("mon an: Thit kho tau")
# Out:
# mon an: Pho
